# %%
## To get individial CIF files

import re
from pathlib import Path


CIF_DIR = Path(".")   


def get_formula(text):
    for line in text.splitlines():
        line = line.strip()
        if line.startswith("_chemical_formula_sum"):
            return (
                line.split(None, 1)[1]
                .replace("'", "")
                .replace('"', "")
                .replace(" ", "")
            )
    return None

def sanitize(name):
    return re.sub(r"[^\w\.\-]", "", name)

for cif_file in CIF_DIR.glob("*.cif"):
    text = cif_file.read_text(errors="ignore")

    # Split on real data_ blocks
    blocks = re.split(r"(?=^data_)", text, flags=re.MULTILINE)
    blocks = [b for b in blocks if b.strip().startswith("data_")]


    if len(blocks) <= 1:
        continue

    print(f"\nProcessing batch CIF: {cif_file.name}")
    print(f"  Found {len(blocks)} entries")

    for i, block in enumerate(blocks, 1):
        formula = get_formula(block)
        if not formula:
            formula = f"{cif_file.stem}_entry{i}"

        formula = sanitize(formula)
        out_path = cif_file.with_name(f"{formula}.cif")

        # Avoid overwrite
        counter = 1
        while out_path.exists():
            out_path = cif_file.with_name(f"{formula}_{counter}.cif")
            counter += 1

        out_path.write_text(block.strip() + "\n")
        print(f"    → wrote {out_path.name}")
# Out:
# Processing batch CIF: A10.cif
#   Found 3 entries
#     → wrote Al2.5Ga2.5Gd3O12_2.cif
#     → wrote Al2Ga3Gd3O12_2.cif
#     → wrote Al3Ga2Gd3O12_2.cif
#
# Processing batch CIF: A12.cif
#   Found 12 entries
#     → wrote Al2.5Ga2.5O12Y3_6.cif
#     → wrote Al2.5Ga2.5O12Y3_7.cif
#     → wrote Al2.5Ga2.5O12Y3_8.cif
#     → wrote Al4GaO12Y3_2.cif
#     → wrote Al3Ga2O12Y3_2.cif
#     → wrote Al2Ga3O12Y3_4.cif
#     → wrote AlGa4O12Y3_2.cif
#     → wrote Al3.97Ga1.03O12Y3_2.cif
#     → wrote Al3.08Ga1.92O12Y3_2.cif
#     → wrote Al2.10Ga2.90O12Y3_2.cif
#     → wrote Al0.92Ga4.08O12Y3_2.cif
#     → wrote Al2Ga3O12Y3_5.cif
#
# Processing batch CIF: A13.cif
#   Found 2 entries
#     → wrote Al3Li9O29P8_2.cif
#     → wrote AlLiO12P4_2.cif
#
# Processing batch CIF: A14.cif
#   Found 5 entries
#     → wrote Al10.26Mg0.74O17Sr0.85_2.cif
#     → wrote Al9.94Mg1.06O17Sr_4.cif
#     → wrote Al9.94Mg1.06O17Sr_5.cif
#     → wrote Al22MgO36Sr1.91_2.cif
#     → wrote Al10MgO17Sr0.92_2.cif
#
# Processing batch CIF: A15.cif
#   Found 2 entries
#     → wrote Al4O15Sc2Sr6_2.cif
#     → wrote Al1.50O5Sc0.50Sr2_2.cif
#
# Processing batch CIF: A22.cif
#   Found 9 entries
#     → wrote CaGe2MgO6_4.cif
#     → wrote CaGe2MgO6_5.cif
#     → wrote CaGeMgO4_10.cif
#     → wrote CaGeMgO4_11.cif
#     → wrote Ca1.16GeMg0.84O4_2.cif
#     → wrote Ca1.07GeMg0.93O4_2.cif
#     → wrote CaGeMgO4_12.cif
#     → wrote CaGeMgO4_13.cif
#     → wrote CaGeMgO4_14.cif
#
# Processing batch CIF: A25.cif
#   Found 2 entries
#     → wrote Ca3Ge3Na0.67O12Zr1.33_2.cif
#     → wrote CaGe3Na2O12Zr2_2.cif
#
# Processing batch CIF: A26.cif
#   Found 3 entries
#     → wrote Ca0.5Hf2O12P3_6.cif
#     → wrote Ca0.5Hf2O12P3_7.cif
#     → wrote Ca0.5Hf2O12P3_8.cif
#
# Processing batch CIF: A28.cif
#   Found 6 entries
#     → wrote CaO3Sb0.5Y0.5_4.cif
#     → wrote CaO3Sb0.5Y0.5_5.cif
#     → wrote Ca2O14Sb3Y3_4.cif
#     → wrote Ca2O6SbY_2.cif
#     → wrote Ca1.80O14Sb3Y3.20_2.cif
#     → wrote Ca2O14Sb3Y3_5.cif
#
# Processing batch CIF: A3.cif
#   Found 6 entries
#     → wrote Al10.37Ba0.82Mg0.63O17_2.cif
#     → wrote Al10.33Ba0.83Mg0.67O17_2.cif
#     → wrote Al9.94Ba0.63Mg1.06O17_2.cif
#     → wrote Al9.94BaMg1.06O17_2.cif
#     → wrote Al10.09Ba0.96Mg0.91O17_2.cif
#     → wrote Al14.10Ba0.94Mg2.50O25_2.cif
#
# Processing batch CIF: A30.cif
#   Found 11 entries
#     → wrote GaGe0.50Mg3.50O6_2.cif
#     → wrote GaGe0.50Mg1.50O4_4.cif
#     → wrote Ga1.11Ge0.43Mg3.47O6_2.cif
#     → wrote Ga3.56Ge1.23Mg2.22O10_2.cif
#     → wrote Ga3.92Ge3.04Mg4.04O16_2.cif
#     → wrote Ga1.84Ge0.08Mg1.08O4_2.cif
#     → wrote Ga1.70Ge0.15Mg1.15O4_2.cif
#     → wrote Ga1.54Ge0.23Mg1.23O4_2.cif
#     → wrote GaGe0.50Mg1.50O4_5.cif
#     → wrote Ga2GeMg3O8_2.cif
#     → wrote GaGe0.5Mg1.5O4_2.cif
#
# Processing batch CIF: A33.cif
#   Found 15 entries
#     → wrote Ga11LaMgO19_6.cif
#     → wrote Ga11LaMgO19_7.cif
#     → wrote Ga0.80LaMg0.20O2.88_2.cif
#     → wrote Ga0.90LaMg0.10O2.90_2.cif
#     → wrote Ga0.90LaMg0.10O2.92_2.cif
#     → wrote Ga0.90LaMg0.10O2.94_4.cif
#     → wrote Ga0.90LaMg0.10O2.94_5.cif
#     → wrote Ga11LaMgO19_8.cif
#     → wrote Ga0.80LaMg0.20O2.90_4.cif
#     → wrote Ga0.80LaMg0.20O2.92_2.cif
#     → wrote Ga0.80LaMg0.20O2.90_5.cif
#     → wrote Ga0.80LaMg0.20O2.94_2.cif
#     → wrote Ga0.9LaMg0.1O2.95_2.cif
#     → wrote Ga0.95LaMg0.05O2.975_2.cif
#     → wrote Ga10.95La0.95MgO19_2.cif
#
# Processing batch CIF: A34.cif
#   Found 3 entries
#     → wrote GaLiO12P4_2.cif
#     → wrote Ga3Li9O29P8_4.cif
#     → wrote Ga3Li9O29P8_5.cif
#
# Processing batch CIF: A35.cif
#   Found 6 entries
#     → wrote Ga0.25Li1.25O4Ti1.5_2.cif
#     → wrote GaLiO4Ti_4.cif
#     → wrote Ga4.70Li0.70O8Ti0.30_2.cif
#     → wrote GaLiO4Ti_5.cif
#     → wrote Ga4.40Li0.91O8Ti0.48_2.cif
#     → wrote Ga0.03Li1.31O4Ti1.66_2.cif
#
# Processing batch CIF: A39.cif
#   Found 9 entries
#     → wrote Ga5O12Yb3_16.cif
#     → wrote Ga5O12Yb3_17.cif
#     → wrote Ga5O12Yb3_18.cif
#     → wrote GaO3Yb_2.cif
#     → wrote Ga5O12Yb3_19.cif
#     → wrote Ga5O12Yb3_20.cif
#     → wrote Ga5O12Yb3_21.cif
#     → wrote Ga5O12Yb3_22.cif
#     → wrote Ga5O12Yb3_23.cif
#
# Processing batch CIF: A4.cif
#   Found 5 entries
#     → wrote AlCa3Ge5O14_2.cif
#     → wrote Al2Ca2GeO7_2.cif
#     → wrote Al2Ca3Ge3O12_6.cif
#     → wrote Al2Ca3Ge3O12_7.cif
#     → wrote Al2Ca3Ge3O12_8.cif
#
# Processing batch CIF: A42.cif
#   Found 4 entries
#     → wrote Ge5MgO14Sr3_4.cif
#     → wrote Ge2MgO7Sr2_4.cif
#     → wrote Ge2MgO7Sr2_5.cif
#     → wrote Ge5MgO14Sr3_5.cif
#
# Processing batch CIF: A43.cif
#   Found 2 entries
#     → wrote In1.59O3Sb0.14Zn0.28_2.cif
#     → wrote InO8SbZn4_2.cif
#
# Processing batch CIF: A44.cif
#   Found 3 entries
#     → wrote K3O8P2Sc_6.cif
#     → wrote K3O8P2Sc_7.cif
#     → wrote K3O8P2Sc_8.cif
#
# Processing batch CIF: A48.cif
#   Found 5 entries
#     → wrote LiMg0.5O3Sn_2.cif
#     → wrote Li0.33Mg0.50OSn0.17_6.cif
#     → wrote Li0.33Mg0.50OSn0.17_7.cif
#     → wrote Li1.60Mg1.60O8Sn2.80_2.cif
#     → wrote Li0.33Mg0.50OSn0.17_8.cif
#
# Processing batch CIF: A51.cif
#   Found 20 entries
#     → wrote Mg0.95O3TiZn0.05_10.cif
#     → wrote Mg0.95O3TiZn0.05_11.cif
#     → wrote Mg0.95O3TiZn0.05_12.cif
#     → wrote Mg0.95O3TiZn0.05_13.cif
#     → wrote Mg0.95O3TiZn0.05_14.cif
#     → wrote Mg0.46O3TiZn0.54_2.cif
#     → wrote Mg0.90O3TiZn0.10_2.cif
#     → wrote Mg0.80O3TiZn0.20_2.cif
#     → wrote Mg0.70O3TiZn0.30_2.cif
#     → wrote Mg0.60O3TiZn0.40_2.cif
#     → wrote Mg0.50O3TiZn0.50_2.cif
#     → wrote Mg0.40O3TiZn0.60_2.cif
#     → wrote Mg0.30O3TiZn0.70_2.cif
#     → wrote Mg0.20O3TiZn0.80_2.cif
#     → wrote Mg0.15O4TiZn1.85_8.cif
#     → wrote Mg0.15O4TiZn1.85_9.cif
#     → wrote Mg0.15O4TiZn1.85_10.cif
#     → wrote Mg0.15O4TiZn1.85_11.cif
#     → wrote Mg0.08O4TiZn1.92_4.cif
#     → wrote Mg0.08O4TiZn1.92_5.cif
#
# Processing batch CIF: A7.cif
#   Found 4 entries
#     → wrote Al1.05Ca2Nb0.94O6_2.cif
#     → wrote Al0.5CaNb0.5O3_2.cif
#     → wrote AlCa2NbO6_4.cif
#     → wrote AlCa2NbO6_5.cif
#
# Processing batch CIF: A9.cif
#   Found 12 entries
#     → wrote AlCaO5Ta_18.cif
#     → wrote AlCaO5Ta_19.cif
#     → wrote AlCaO5Ta_20.cif
#     → wrote AlCaO5Ta_21.cif
#     → wrote AlCaO5Ta_22.cif
#     → wrote AlCaO5Ta_23.cif
#     → wrote AlCaO5Ta_24.cif
#     → wrote AlCaO5Ta_25.cif
#     → wrote Al0.94Ca2O6Ta1.06_2.cif
#     → wrote Al0.5CaO3Ta0.5_2.cif
#     → wrote AlCaO5Ta_26.cif
#     → wrote AlCa2O6Ta_2.cif
